# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=("C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv")
visa_df=pd.read_csv(file_path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
-we read p_wage column
-we perform statistical analysis
-we perform imperical rule analysis
-imperical rule:68-95-99.7
-p_wage:67.3-96-98
-wage_mean:74455
-wage_median:70308
-median<mean
-data might be right-skewed
-but percentage of data almost vailed with imperical rule
-it will looks normal distribution and slightly right skewed
-in order to see that draw histrogram

# %% [markdown]
# $histogram$

# %%
plt.hist(visa_df["prevailing_wage"],bins=40)
#by default it will give as 10 intervals
#if you want increase the intervals
#argument name bins
plt.show()

# %%
plt.hist(visa_df["prevailing_wage"],bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
# ...

# %%
2992. obervations between 2.13670000e+00, 7.98234003e+03
871.  observations between 7.98234003e+03, 1.59625434e+04
# Out:
# (2.1367, 7982.34003)

# %%
frequency,interval,n=plt.hist(visa_df["prevailing_wage"],bins=40)
#frequency means number of observations are fall between an interval
#interval
#the nuber of intervals

# %%
len(frequency)
# Out:
# 40

# %%
len(interval)
# Out:
# 41

# %%
len(n)
# Out:
# 40

# %%
con1=visa_df["prevailing_wage"]>2.13
con2=visa_df["prevailing_wage"]<7982.3
len(visa_df[con1&con2])
# Out:
# 2992

# %%
len(visa_df[visa_df["prevailing_wage"].between(2.1367,7982.3)])
# Out:
# 2992

# %% [markdown]
# $outlier-analysis$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=("C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv")
visa_df=pd.read_csv(file_path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $box-plot$

# %% [markdown]
# <img class="mimg rms_img" style="color: rgb(203, 178, 0);" height="174" width="309" alt="Image result for boxplot" id="emb15F556D3C" src="data:image/jpeg;base64,..." data-thhnrepbd="1" data-bm="144">

# %% [markdown]
# <img class="mimg vimgld" style="color: rgb(201, 151, 2);" height="180" width="163" alt="Image result for boxplot" data-thhnrepbd="1" src="https://th.bing.com/th/id/OIP.UFs5bi1MEARl9b3uLPbO1AHaHa?w=163&amp;h=180&amp;c=7&amp;r=0&amp;o=5&amp;dpr=1.3&amp;pid=1.7" data-bm="196">

# %%
outlier-formula

# %%
mild-outlier=q3+1.5*iqr
huge-otlier=q1-1.5*iqr

# %%
plt.boxplot(visa_df["prevailing_wage"],vert=False)    #vert=vertical
plt.show()

# %% [markdown]
# $dealing-outliers$

# %%
-removal of outliers
-impute the outliers with median value
  -because median is not imapct by outliers
-cap the outliers with Q3 which are having more than Q3
-cap the outliers with Q1 which are having less than Q1

# %%
step-1:calculate q1,q2,q3
step-2:calculate IQR=(q3-q1)
step-3:ub=q3+1.5*iqr
step-4:lb=q1-1.5*iqr
step-5:con1=col>ub
step-6:con2=col<lb
step-7:con1|con2
step-8:col[con1|con2]

# %%
q1=round(np.percentile(visa_df["prevailing_wage"],25),2)
q2=round(np.percentile(visa_df["prevailing_wage"],50),2)
q3=round(np.percentile(visa_df["prevailing_wage"],75),2)
print(q1,q2,q3)
iqr=(q3-q1)
print(iqr)
ub=q3+1.5*iqr
lb=q1-1.5*iqr
print(ub,lb)
con1=visa_df["prevailing_wage"]>ub
con2=visa_df["prevailing_wage"]<lb
outliers=(visa_df["prevailing_wage"][con1|con2])
outliers_data=outliers.values
len(outliers_data)
#for only one column["prevailing_wage"]
# Out:
# 34015.48 70308.21 107735.51
# 73720.03
# 218315.555 -76564.565
# 427

# %%
def outlier_data():
    q1=round(np.percentile(visa_df["prevailing_wage"],25),2)
    q2=round(np.percentile(visa_df["prevailing_wage"],50),2)
    q3=round(np.percentile(visa_df["prevailing_wage"],75),2)
    print(q1,q2,q3)
    iqr=(q3-q1)
    print(iqr)
    ub=q3+1.5*iqr
    lb=q1-1.5*iqr
    print(ub,lb)
    con1=visa_df["prevailing_wage"]>ub
    con2=visa_df["prevailing_wage"]<lb
    outliers=(visa_df["prevailing_wage"][con1|con2])
    outliers_data=outliers.values
    return(outliers_data)

# %%
outliers_data=outlier_data()
len(outliers_data)
# Out:
# 34015.48 70308.21 107735.51
# 73720.03
# 218315.555 -76564.565
# 427

# %%
q1=round(np.percentile(visa_df["prevailing_wage"],25),2)
q2=round(np.percentile(visa_df["prevailing_wage"],50),2)
q3=round(np.percentile(visa_df["prevailing_wage"],75),2)
print(q1,q2,q3)
iqr=(q3-q1)
print(iqr)
ub=q3+1.5*iqr
lb=q1-1.5*iqr
print(ub,lb)
con1=visa_df["prevailing_wage"]>ub
con2=visa_df["prevailing_wage"]<lb
outliers=(visa_df[con1|con2])
outliers
#outliers of full dataframe
# Out:
# 34015.48 70308.21 107735.51
# 73720.03
# 218315.555 -76564.565
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
# ...

# %%
len(outliers_data),len(visa_df),len(outliers_data)*100/len(visa_df)
# Out:
# (427, 25480, 1.6758241758241759)

# %% [markdown]
# $case-1$:removal of outliers

# %%
-we have 427 outliers in prevailing_wage column
-we need to remove 427 rows from entire data frame

# %%
q1=round(np.percentile(visa_df["prevailing_wage"],25),2)
q2=round(np.percentile(visa_df["prevailing_wage"],50),2)
q3=round(np.percentile(visa_df["prevailing_wage"],75),2)
print(q1,q2,q3)
iqr=(q3-q1)
print(iqr)
ub=q3+1.5*iqr
lb=q1-1.5*iqr
print(ub,lb)
con1=visa_df["prevailing_wage"]<ub
con2=visa_df["prevailing_wage"]>lb
non_outliers=(visa_df[con1&con2])
non_outliers
# Out:
# 34015.48 70308.21 107735.51
# 73720.03
# 218315.555 -76564.565
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
plt.boxplot(non_outliers["prevailing_wage"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e46e513590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e46e0d4fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e46e0df550>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e46e462450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e46e0ecc50>],
#  'means': []}

# %%
plt.hist(non_outliers["prevailing_wage"],bins=40)
# Out:
# (array([2729.,  591.,  592.,  668.,  741.,  840.,  849.,  938.,  971.,
#          950.,  962., 1007.,  998.,  999.,  954.,  991.,  941.,  885.,
#          868.,  813.,  832.,  702.,  697.,  629.,  497.,  449.,  391.,
#          306.,  255.,  187.,  163.,  101.,   85.,   68.,   79.,   63.,
#           76.,   68.,   63.,   55.]),
#  array([2.13670000e+00, 5.45444853e+03, 1.09067604e+04, 1.63590722e+04,
#         2.18113840e+04, 2.72636959e+04, 3.27160077e+04, 3.81683195e+04,
#         4.36206314e+04, 4.90729432e+04, 5.45252550e+04, 5.99775669e+04,
#         6.54298787e+04, 7.08821905e+04, 7.63345024e+04, 8.17868142e+04,
#         8.72391260e+04, 9.26914379e+04, 9.81437497e+04, 1.03596062e+05,
#         1.09048373e+05, 1.14500685e+05, 1.19952997e+05, 1.25405309e+05,
#         1.30857621e+05, 1.36309933e+05, 1.41762244e+05, 1.47214556e+05,
#         1.52666868e+05, 1.58119180e+05, 1.63571492e+05, 1.69023804e+05,
#         1.74476115e+05, 1.79928427e+05, 1.85380739e+05, 1.90833051e+05,
# ...

# %% [markdown]
# $using-subplot$

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.title("non_outliers_data")
plt.hist(non_outliers["prevailing_wage"],bins=40)
plt.subplot(2,2,2)
plt.title("original_data")
plt.hist(visa_df["prevailing_wage"],bins=40)
plt.subplot(2,2,3)
plt.title("non_outliers_data")
plt.boxplot(non_outliers["prevailing_wage"],vert=False)
plt.subplot(2,2,4)
plt.title("original_data")
plt.boxplot(visa_df["prevailing_wage"],vert=False)
plt.tight_layout()

# %% [markdown]
# $case-2$:
#     impute with median

# %%
-we got pre_wage has 427 outliers
-we replace those 427 with median value of pre_wage

# %%
ub,lb
# Out:
# (218315.555, -76564.565)

# %%
median=visa_df["prevailing_wage"].median()
median
# Out:
# 70308.20999999999

# %%
#iterate through pre_wage
#if a value>ub or <ld===>median
# else:i

# %%
new_value=[]
median=round(visa_df["prevailing_wage"].median(),2)
for i in visa_df["prevailing_wage"].values:
    if i>ub :
        new_value.append(median)
    else:
        new_value.append(i)

# %%
new_value
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  70308.21,
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  70308.21,
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
#  121316.5,
#  122540.55,
#  47170.76,
#  330.3743,
# ...

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
