# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path=("C:\\Users\\shrav\\Downloads\\train_ctrUa4K.csv")
train_df=pd.read_csv(file_path)
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# $shape$

# %%
train_df.shape
# Out:
# (614, 13)

# %%
type(train_df.shape)
# Out:
# tuple

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("the no of rows:",train_df.shape[0])
print("the no of columns:",train_df.shape[1])
# Out:
# the no of rows: 614
# the no of columns: 13

# %% [markdown]
# $size$

# %%
train_df.size
# Out:
# 7982

# %%
train_df.shape[0]*train_df.shape[1]
# Out:
# 7982

# %% [markdown]
# $columns$

# %%
train_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
train_df["Loan_ID"]
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
type(train_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
train_df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')>

# %%
train_df.columns.to_list()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# $dtypes$

# %%
train_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
type(train_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
train_df.dtypes.keys()
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
train_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('int64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('O'), dtype('O')],
#       dtype=object)

# %%
dict1=(train_df.dtypes)
for i,j in dict1.items():
    if j=="object":
        print(i)
# Out:
# Loan_ID
# Gender
# Married
# Dependents
# Education
# Self_Employed
# Property_Area
# Loan_Status

# %%
dict1=(train_df.dtypes)
for i,j in dict1.items():
    if j=="int64":
        print(i)
# Out:
# ApplicantIncome

# %%
dict1=(train_df.dtypes)
for i,j in dict1.items():
    if j=="float64":
        print(i)
# Out:
# CoapplicantIncome
# LoanAmount
# Loan_Amount_Term
# Credit_History

# %% [markdown]
# $head$

# %%
train_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train_df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %% [markdown]
# $tail$

# %%
train_df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %% [markdown]
# $take$

# %%
train_df.take([610,611],axis=0)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y

# %%
train_df.take([11,12],axis=1).take([610,611])
# Out:
#     Property_Area Loan_Status
# 610         Rural           Y
# 611         Urban           Y

# %%
train_df.take([11,12],axis=1)
# Out:
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# 3           Urban           Y
# 4           Urban           Y
# ..            ...         ...
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# 613     Semiurban           N
#
# [614 rows x 2 columns]

# %%
train_df.iloc[100:150]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 100  LP001345    Male     Yes          2  Not Graduate            No
# 101  LP001349    Male      No          0      Graduate            No
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 103  LP001356    Male     Yes          0      Graduate            No
# 104  LP001357    Male     NaN        NaN      Graduate            No
# 105  LP001367    Male     Yes          1      Graduate            No
# 106  LP001369    Male     Yes          2      Graduate            No
# 107  LP001370    Male      No          0  Not Graduate           NaN
# 108  LP001379    Male     Yes          2      Graduate            No
# 109  LP001384    Male     Yes         3+  Not Graduate            No
# 110  LP001385    Male      No          0      Graduate            No
# 111  LP001387  Female     Yes          0      Graduate           NaN
# 112  LP001391    Male     Yes          0  Not Graduate            No
# ...

# %%
train_df.replace({"3+":"4"})
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df["Dependents"].replace({"3+":4},inplace=True)
train_df['Dependents']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 609    0
# 610    4
# 611    1
# 612    2
# 613    0
# Name: Dependents, Length: 614, dtype: object
