# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $one-hot-encoder$

# %%
-one hot encoder means at a time only one will be ON(1/TRUE) others are OFF(0/FALSE)
-suppose case_status has two unique labels
-certified and denied
-in one hot encoder it will create two new columns
-like below

# %% [markdown]
# |case_status|certified|denied|
# |-----------|---------|------|
# |certified|1|0|
# |denied|0|1|

# %%
-one hot encoder new columns are orthogonal each other
-orthogonal means 90 degrees phase shift
-90 degrees phase shift means perpendicular each other
-perpendicular means independent each other
-independent means no relation
-it is very important property  that is to avoid realtion between variables

# %% [markdown]
# $drawback$

# %%
-assume that you have 100 unique labels for a column
-so it will create 100 new columns
-to process 100 columns we require more memory,more time,more hardware
-this is called curse of dimensionality

# %% [markdown]
# $pd.get-dummeies-method$

# %%
pd.get_dummies(visa_df,columns=["case_status"])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
pd.get_dummies(visa_df,columns=["continent"])
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %%
pd.get_dummies(visa_df,columns=["continent"],dtype="int")
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %% [markdown]
# $normalization&standardization$

# %%
-in every dataset we have different columns has different units
-in every dataset we have different columns has values varies from -inf to inf
-it is very important standardize the data,make sure all the column under same range
-to achieve this we have two methods:
    -normalization
    -standardization

# %% [markdown]
# **normalization**
# *x min max scaler*
# <img class="mimg rms_img" style="color: rgb(81, 83, 88);" height="86" width="349" alt="Image result for Normalization formula" id="emb4B9BC0DC" src="data:image/jpeg;base64,..." data-thhnrepbd="1" data-bm="90">

# %% [markdown]
# **standardization**
# Z-score
# <img class="mimg" style="color: rgb(102, 102, 102);" height="180" width="303" src="https://th.bing.com/th/id/OIP.mmO8G4jCsp8ifwBSOqkT7wHaED?w=303&amp;h=180&amp;c=7&amp;r=0&amp;o=5&amp;dpr=1.3&amp;pid=1.7" alt="Image result for standardization formula" data-thhnrepbd="1" data-bm="109">

# %%
# step-1:calculate min value of p_wage=minn
# step-2:maxx of p_wage
# step-3:dr=maxx/minn
# step-4:nr=p_wage/minn
# step-5:nr/dr

# %%
minn=min(visa_df["prevailing_wage"])
maxx=max(visa_df["prevailing_wage"])
dr=maxx-minn
nr=visa_df["prevailing_wage"]-minn
visa_df["prevailing_wage_num"]=nr/dr

# %%
visa_df["prevailing_wage_num"]
# Out:
# 0        0.001849
# 1        0.261345
# 2        0.385312
# 3        0.261371
# 4        0.469616
#            ...
# 25475    0.241505
# 25476    0.874579
# 25477    0.458311
# 25478    0.269895
# 25479    0.222033
# Name: prevailing_wage_num, Length: 25480, dtype: float64

# %%
visa_df["preaviling_wage_num"]=nr/dr
visa_df[["prevailing_wage","prevailing_wage_num"]]
# Out:
#        prevailing_wage  prevailing_wage_num
# 0             592.2029             0.001849
# 1           83425.6500             0.261345
# 2          122996.8600             0.385312
# 3           83434.0300             0.261371
# 4          149907.3900             0.469616
# ...                ...                  ...
# 25475       77092.5700             0.241505
# 25476      279174.7900             0.874579
# 25477      146298.8500             0.458311
# 25478       86154.7700             0.269895
# 25479       70876.9100             0.222033
#
# [25480 rows x 2 columns]

# %%
visa_df["prevailing_wage_num"].max()
# Out:
# 1.0

# %%
visa_df["prevailing_wage_num"].min()
# Out:
# 0.0

# %%
visa_df["prevailing_wage"].max(),visa_df["prevailing_wage"].max()
# Out:
# (319210.27, 319210.27)

# %%
max_id=visa_df["prevailing_wage_num"].idxmax()
min_id=visa_df["prevailing_wage_num"].idxmin()
max_id,min_id
# Out:
# (21077, 20575)

# %%
visa_df[["prevailing_wage","prevailing_wage_num"]].iloc[[max_id,min_id]]
# Out:
#        prevailing_wage  prevailing_wage_num
# 21077      319210.2700                  1.0
# 20575           2.1367                  0.0

# %% [markdown]
# $min-max-scalar$

# %%
-MinMaxScalar is a method from sklearn preprocessing
-read the package
-save the package
-apply fir transform

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
mms.fit_transform(visa_df[["prevailing_wage"]])
# Out:
# array([[0.00184853],
#        [0.2613452 ],
#        [0.385312  ],
#        ...,
#        [0.45831136],
#        [0.26989486],
#        [0.22203311]])

# %% [markdown]
# **note**:
#     inside MinMaxscaler pass a dataframe not series

# %%
#array
v1=np.array([[[1,2,3,4,5]]])
v1.ndim
# Out:
# 3

# %%
visa_df["prevailing_wage_num"]=mms.fit_transform(visa_df[["prevailing_wage"]])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $z-score$
# <img class="mimg" style="color: rgb(102, 102, 102);" height="180" width="303" src="https://th.bing.com/th/id/OIP.mmO8G4jCsp8ifwBSOqkT7wHaED?w=303&amp;h=180&amp;c=7&amp;r=0&amp;o=5&amp;dpr=1.3&amp;pid=1.7" alt="Image result for standardization formula" data-thhnrepbd="1" data-bm="109">

# %%
# step-1:calculate min value of p_wage=minn
# step-2:maxx of p_wage
# step-3:dr=maxx/minn
# step-4:nr=p_wage/minn
# step-5:nr/dr

# %%
mean=visa_df["prevailing_wage"].mean()
std=visa_df["prevailing_wage"].std()
z=visa_df["prevailing_wage"]-mean
visa_df["prevailing_wage_zscore"]=z/std

# %%
visa_df[["prevailing_wage","prevailing_wage_zscore"]]
# Out:
#        prevailing_wage  prevailing_wage_zscore
# 0             592.2029               -1.398510
# 1           83425.6500                0.169832
# 2          122996.8600                0.919060
# 3           83434.0300                0.169991
# 4          149907.3900                1.428576
# ...                ...                     ...
# 25475       77092.5700                0.049923
# 25476      279174.7900                3.876083
# 25477      146298.8500                1.360253
# 25478       86154.7700                0.221504
# 25479       70876.9100               -0.067762
#
# [25480 rows x 2 columns]

# %%
plt.subplot(1,2,1)
plt.boxplot(visa_df["prevailing_wage"])
plt.subplot(1,2,2)
plt.boxplot(visa_df["prevailing_wage_zscore"])
plt.show()

# %% [markdown]
# $StandardScaler$

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
ss.fit_transform(visa_df[["prevailing_wage"]])
# Out:
# array([[-1.39853722],
#        [ 0.1698353 ],
#        [ 0.91907852],
#        ...,
#        [ 1.36027953],
#        [ 0.22150859],
#        [-0.06776315]])

# %%
visa_df["preaviling_wage_zscore"]=ss.fit_transform(visa_df[["prevailing_wage"]])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
q1=np.percentile(visa_df["prevailing_wage_zscore"],25)
q2=np.percentile(visa_df["preaviling_wage_zscore"],50)
q3=np.percentile(visa_df["prevailing_wage_zscore"],75)
iqr=q3-q1
ub=q3+1.5*iqr
lb=q1-1.5*iqr
con1=visa_df["prevailing_wage_zscore"]>ub
con2=visa_df["prevailing_wage_zscore"]<lb
con=con1|con2
visa_df["prevailing_wage_zscore"][con]
# Out:
# 14       2.757234
# 34       2.861142
# 130      3.274337
# 216      3.689527
# 221      2.746781
#            ...
# 25191    3.900843
# 25195    3.026604
# 25468    3.753789
# 25469    3.773797
# 25476    3.876083
# Name: prevailing_wage_zscore, Length: 427, dtype: float64
