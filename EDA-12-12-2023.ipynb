# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %% [markdown]
# $bar-plot-using-seaborn$

# %%
#in order to draw a bar chat we required frequency table
#continent column
#we created one more dataframe
#having each lable frequency
#asia 16k
#africa

#the above things are required ,if you want to draw bar chart using matplotlib
#seaborn will take directly the original column from original data

# %% [markdown]
# matplotlib bar chart requires 3 valuess
# -x-axis=cat
# -y-axis=numerical
# -data name
# -from original dataframe visadf,the original column is continent
# -we created another table which has lables and its count
# continents	count
# 0	Asia	16861
# 1	Europe	3732
# 2	North America	3292
# 3	South America	852
# 4	Africa	551
# 5	Oceania	192

# %%
-seaborn requires 2 values
-data:original dataframe
-x axis:original column name:"continent"

# %%
import seaborn as sns
sns.countplot(data=visa_df,x="continent")
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
import seaborn as sns
labels=["Asia","Europe","North America","South America","Africa","Oceania"]
sns.countplot(data=visa_df,x="continent",order=labels)
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
visa_df["continent"].value_counts().values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
import seaborn as sns
labels=visa_df["continent"].value_counts().keys()
plt.figure(figsize=(10,5))
plt.title("bar chart")
sns.countplot(data=visa_df,x="continent",order=labels)
plt.show()

# %%
#m-1: using matplotlib
===================================reading the data==========================================================
file_path="C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
===================================create a frequency table==================================================
visa_df["continent"].value_counts()
continents=visa_df["continent"].value_counts().keys()
count=visa_df["continent"].value_counts().values
contint_data=pd.DataFrame(zip(continents,count),columns=["continents","count"])
contint_data
===================================plot======================================================================
plt.figure(figsize=(10,5))
#10=x-axis
#5=y-axis
plt.bar("continents","count",data=contint_data)
plt.title("Bar Chart")
plt.xlabel("continents")
plt.ylabel("count")
plt.savefig("continents_bar.jpg")
plt.show()

# %%
#m-2:using seaborn
=========================read the data========================================
file_path="C:\\Users\\shrav\\Downloads\\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(file_path)
=============================plot=============================================
import seaborn as sns
labels=visa_df["continent"].value_counts().keys()
plt.figure(figsize=(10,5))
plt.title("bar chart")
sns.countplot(data=visa_df,x="continent",order=labels)
plt.show()

# %%
#methos-3:using valuecounts
count=visa_df["continent"].value_counts()
ax=count.plot(kind="bar")
#ax.bar_label(ax.containers[0])   #ax:axis,to get numbers ax.bar_label

# %%
#m-4:
count=visa_df["continent"].value_counts()
ax=count.plot(kind="bar")
ax.bar_label(ax.containers[0])
plt.show()
#to get the numbers on each bar

# %% [markdown]
# $pie-chart$

# %%
keys=visa_df["continent"].value_counts(normalize=True).keys()
values=visa_df["continent"].value_counts(normalize=True).values
pd.DataFrame(zip(keys,values),columns=["continent","Relative frequency"])
# Out:
#        continent  Relative frequency
# 0           Asia            0.661735
# 1         Europe            0.146468
# 2  North America            0.129199
# 3  South America            0.033438
# 4         Africa            0.021625
# 5        Oceania            0.007535

# %%
plt.pie(x=values,labels=keys,autopct="%0.2f%%",startangle=360,radius=3,explode=[0.1,2,3,4,5,6])
plt.show()

# %%
visa_df["case_status"].value_counts()
continents=visa_df["case_status"].value_counts().keys()
count=visa_df["case_status"].value_counts().values
contint_data=pd.DataFrame(zip(continents,count),columns=["case_status","count"])
contint_data
# Out:
#   case_status  count
# 0   Certified  17018
# 1      Denied   8462

# %%
data_types=dict(visa_df.dtypes)
cat=[i for i in data_types if data_types[i]=="O"]
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
i="continent"
visa_df[i].value_counts()
value1=visa_df[i].value_counts().keys()
value2=visa_df[i].value_counts().values
data=pd.DataFrame(zip(continents,count),columns=[i,"count"])
contint_data
# Out:
#   case_status  count
# 0   Certified  17018
# 1      Denied   8462

# %%
for i in cat:
    visa_df[i].value_counts()
    value1=visa_df[i].value_counts().keys()
    value2=visa_df[i].value_counts().values
    data=pd.DataFrame(zip(value1,value2),columns=[i,"count"])
    print(data)
# Out:
#          case_id  count
# 0         EZYV01      1
# 1      EZYV16995      1
# 2      EZYV16993      1
# 3      EZYV16992      1
# 4      EZYV16991      1
# ...          ...    ...
# 25475   EZYV8492      1
# 25476   EZYV8491      1
# 25477   EZYV8490      1
# 25478   EZYV8489      1
# 25479  EZYV25480      1
#
# [25480 rows x 2 columns]
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192
#   has_job_experience  count
# 0                  Y  14802
# 1                  N  10678
#   requires_job_training  count
# 0                     N  22525
# 1                     Y   2955
#   region_of_employment  count
# 0            Northeast   7195
# 1                South   7017
# 2                 West   6586
# 3              Midwest   4307
# 4               Island    375
#   unit_of_wage  count
# 0         Year  22962
# 1         Hour   2157
# 2         Week    272
# 3        Month     89
#   full_time_position  count
# 0                  Y  22773
# 1                  N   2707
#   case_status  count
# 0   Certified  17018
# 1      Denied   8462

# %%
for i in cat[1:]:
    visa_df[i].value_counts()
    value1=visa_df[i].value_counts().keys()
    value2=visa_df[i].value_counts().values
    data=pd.DataFrame(zip(value1,value2),columns=[i,"count"])
    print(data)
    data.to_csv(file_path+"{}.csv".format(i))
    file_path+"{}.csv".format(i)
# Out:
#        continent  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192
#   has_job_experience  count
# 0                  Y  14802
# 1                  N  10678
#   requires_job_training  count
# 0                     N  22525
# 1                     Y   2955
#   region_of_employment  count
# 0            Northeast   7195
# 1                South   7017
# 2                 West   6586
# 3              Midwest   4307
# 4               Island    375
#   unit_of_wage  count
# 0         Year  22962
# 1         Hour   2157
# 2         Week    272
# 3        Month     89
#   full_time_position  count
# 0                  Y  22773
# 1                  N   2707
#   case_status  count
# 0   Certified  17018
# 1      Denied   8462

# %%
file_path=("C:\\Users\\shrav\\Desktop\\EDA with python\\continent\\")

# %%
file_path+"{}.csv".format(i)
# Out:
# 'C:\\Users\\shrav\\Desktop\\EDA with python\\continent\\case_status.csv'

# %%
plt.subplot(2,2,3)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
continents=visa_df['continent'].value_counts().keys()
count=visa_df['continent'].value_counts().values
contint_data=pd.DataFrame(zip(continents,count),columns=["Continents","Count"])
# Create a subplot with a 1x1 grid (you can adjust this based on your needs)
fig, ax = plt.subplots(3,4)
ax[0][0].barh(contint_data["Continents"],contint_data["Count"])
plt.tight_layout()
